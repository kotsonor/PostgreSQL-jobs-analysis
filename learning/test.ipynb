# %%
import os
from sqlalchemy import create_engine
import pandas as pd


sql_key = os.getenv("sql_key")

# %%
engine = create_engine(f"postgresql://postgres:{sql_key}@localhost:5432/sql_course")

query = "SELECT * FROM job_postings_fact LIMIT 5;"
df = pd.read_sql(query, engine)
df.head()
# Out:
#    job_id  company_id       job_title_short  \
# 0   31266        1526  Senior Data Engineer
# 1   31280        1172          Data Analyst
# 2   31295        1528          Data Analyst
# 3   31297        1529  Senior Data Engineer
# 4   31314        1530   Senior Data Analyst
#
#                               job_title    job_location  \
# 0              Senior Big Data Engineer           Chile
# 1  Data Analyst Supporting the FBI Jobs  Washington, DC
# 2            Data Analyst at Triggerise  Nairobi, Kenya
# 3                  Senior Data Engineer    New York, NY
# 4                HR Analytics Executive        Thailand
#
#                                          job_via job_schedule_type  \
# 0  via Trabajo.org - Vacantes De Empleo, Trabajo         Full-time
# 1                             via Clearance Jobs         Full-time
# 2                                via Trabajo.org         Full-time
# 3                                   via LinkedIn         Full-time
# ...

# %%
from sqlalchemy import text
import pandas as pd

with open("/Users/sonor/Documents/Projekty/sql-project/1_top10_paying_jobs.sql", "r", encoding="utf-8") as f:
    query = f.read()



df = pd.read_sql(text(query), engine)
df
# Out:
#                                            job_title  \
# 0                                     Data Scientist
# 1                              Senior Data Scientist
# 2                                       Data Analyst
# 3  Geographic Information Systems Analyst - GIS A...
# 4              Staff Data Scientist/Quant Researcher
# 5          Staff Data Scientist - Business Analytics
# 6               Hybrid - Data Engineer - Up to $600k
# 7                              Senior Data Scientist
# 8                         VP Data Science & Research
# 9                         Data Engineer (L4) - Games
#
#                                   company_name            job_location  \
# 0  East River Electric Power Cooperative, Inc.             Madison, SD
# 1                            MSP Staffing  LTD  Pretoria, South Africa
# 2                                       Mantys                  Remote
# 3                                      ReServe            New York, NY
# ...
